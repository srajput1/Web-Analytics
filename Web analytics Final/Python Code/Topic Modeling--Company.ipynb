# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics

from nltk.cluster import KMeansClusterer, cosine_distance

import json
from numpy.random import shuffle

import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split


from sklearn.decomposition import LatentDirichletAllocation

from scipy.cluster.hierarchy import cut_tree

from sklearn import metrics
import numpy as np

import csv

from sklearn.cluster import KMeans

from scipy.cluster.hierarchy import linkage,dendrogram
import matplotlib.pyplot as plt
# %matplotlib inline 

from sklearn.metrics.pairwise import cosine_similarity


from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

from sklearn.decomposition import LatentDirichletAllocation

import matplotlib.pyplot as plt
from wordcloud import WordCloud
import math

# %%
list_to_use1 = ['Microsoft_neg','Microsoft_pos','Netflix_neg','Netflix_pos','amazon_neg',\
                'amazon_pos','Boeing_neg','Boeing_pos','Google_neg','Google_pos','Facebook_neg','Facebook_pos']
for company in list_to_use1:
    with open("C:/Users/rajpu/Desktop/Web analytics Final/Data/"+company+".csv", "r") as f:
        reader=csv.reader(f, delimiter=',') 
        rows=[(row[1][2],row[1][4]) \
          for row in enumerate(reader)]
    shuffle(rows)
#rows
    text,label=zip(*rows)
    text=list(text)
    label=list(label)
   
    # LDA can only use raw term counts for LDA 
    tf_vectorizer = CountVectorizer(max_df=0.90, \
                    min_df=5, stop_words='english')
    tf = tf_vectorizer.fit_transform(text)
    
    # each feature is a word (bag of words)
    # get_feature_names() gives all words
    tf_feature_names = tf_vectorizer.get_feature_names()
    
    #print(tf_feature_names[0:10])
    #print(tf.shape)
    
    
    # split dataset into train (90%) and test sets (10%)
    # the test sets will be used to evaluate proplexity of topic modeling
    X_train, X_test = train_test_split(\
                    tf, test_size=0.1, random_state=0)
    
    num_topics = 1

    # Run LDA. For details, check
    # http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html#sklearn.decomposition.LatentDirichletAllocation.perplexity

    # max_iter control the number of iterations 
    # evaluate_every determines how often the perplexity is calculated
    # n_jobs is the number of parallel threads
    lda = LatentDirichletAllocation(n_components=num_topics, \
                                        max_iter=10,verbose=1,
                                        evaluate_every=1, n_jobs=1,
                                        random_state=0).fit(X_train)
    num_top_words=20
    print(company)

    # lda.components_ returns a KxN matrix
    # for word distribution in each topic.
    # Each row consists of 
    # probability (counts) of each word in the feature space

    for topic_idx, topic in enumerate(lda.components_):
        print ("Topic %d:" % (topic_idx))
        # print out top 20 words per topic 
        words=[(tf_feature_names[i],topic[i]) for i in topic.argsort()[::-1][0:num_top_words]]
        print(words)
        print("\n")
        num_top_words=50
        #f, axarr = plt.subplots(2, 2, figsize=(8, 8));

        #for topic_idx, topic in enumerate(lda.components_):
    # create a dataframe with two columns (word, weight) for each topic
    
    # create a word:count dictionary
           # f={tf_feature_names[i]:topic[i] for i in topic.argsort()[::-1][0:num_top_words]}
    
    # generate wordcloud in subplots
    for topic_idx, topic in enumerate(lda.components_):
        f = {tf_feature_names[i]:topic[i] for i in
                topic.argsort()[::-1][0:num_top_words]}
        wordcloud = WordCloud(width=480,height=450,margin=0,background_color='black')
        wordcloud.generate_from_frequencies(frequencies=f)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.show()
# Out:
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 27.1360
# iteration: 2 of max_iter: 10, perplexity: 25.9587
# iteration: 3 of max_iter: 10, perplexity: 25.5995
# iteration: 4 of max_iter: 10, perplexity: 25.4441
# iteration: 5 of max_iter: 10, perplexity: 25.3646
# Microsoft_neg
# Topic 0:
# [('said', 23.838857751076674), ('company', 19.007555191721913), ('percent', 17.256132917076517), ('year', 12.332684351327289), ('according', 11.210482200286972), ('companies', 10.590425504058759), ('business', 10.556745131364202), ('page', 9.9394552693959195), ('investors', 8.7871683018870197), ('new', 8.2933126737512559), ('think', 7.5417317032126476), ('2018', 7.0708077897125152), ('public', 7.0577264003660858), ('home', 7.0095669797397662), ('reporting', 6.9616506729827492), ('financial', 6.4143432019972488), ('feedback', 5.8014826163890394), ('interested', 5.2595887271028259), ('markets', 5.223551055998227), ('tell', 5.1564095439475288)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 86.3116
# iteration: 2 of max_iter: 10, perplexity: 82.9652
# iteration: 3 of max_iter: 10, perplexity: 81.9734
# iteration: 4 of max_iter: 10, perplexity: 81.5497
# iteration: 5 of max_iter: 10, perplexity: 81.3342
# iteration: 6 of max_iter: 10, perplexity: 81.2126
# iteration: 7 of max_iter: 10, perplexity: 81.1389
# Microsoft_pos
# Topic 0:
# [('percent', 51.038663813992954), ('data', 48.229975074013417), ('mr', 34.868287972542618), ('billion', 34.064405645762747), ('companies', 31.233045961033248), ('company', 28.507987835144153), ('investors', 28.473990741975602), ('growth', 26.33365037220295), ('million', 24.91229877289129), ('value', 24.229381746315028), ('people', 22.853556185664772), ('facebook', 22.809414852702773), ('market', 22.134432218695721), ('trump', 22.098087863546965), ('like', 20.031462617941461), ('apple', 19.30710352709832), ('business', 18.654253899777871), ('economy', 17.891599461593174), ('president', 16.504452064786207), ('years', 16.452284523871874)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 104.9253
# iteration: 2 of max_iter: 10, perplexity: 100.2568
# iteration: 3 of max_iter: 10, perplexity: 98.8436
# iteration: 4 of max_iter: 10, perplexity: 98.2342
# iteration: 5 of max_iter: 10, perplexity: 97.9227
# iteration: 6 of max_iter: 10, perplexity: 97.7463
# iteration: 7 of max_iter: 10, perplexity: 97.6392
# iteration: 8 of max_iter: 10, perplexity: 97.5708
# Netflix_neg
# Topic 0:
# [('percent', 45.617943898291273), ('mr', 39.710207996888009), ('billion', 36.727260256484385), ('company', 33.672917361682039), ('year', 31.477267294273538), ('new', 28.488519137287536), ('trump', 27.755299594698009), ('president', 23.307698515869589), ('deal', 19.59715644007823), ('companies', 19.57497373155908), ('business', 19.563960756230884), ('shares', 19.555912927830608), ('million', 18.106792707082441), ('investors', 18.06790261105445), ('make', 17.37670941973267), ('bank', 17.372710159719713), ('price', 16.628738068933249), ('bloomberg', 15.164683226405671), ('market', 14.39146352955286), ('like', 12.945622866232732)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 134.9251
# iteration: 2 of max_iter: 10, perplexity: 129.3034
# iteration: 3 of max_iter: 10, perplexity: 127.6286
# iteration: 4 of max_iter: 10, perplexity: 126.9114
# iteration: 5 of max_iter: 10, perplexity: 126.5462
# iteration: 6 of max_iter: 10, perplexity: 126.3399
# iteration: 7 of max_iter: 10, perplexity: 126.2149
# iteration: 8 of max_iter: 10, perplexity: 126.1352
# Netflix_pos
# Topic 0:
# [('percent', 67.884676153247597), ('mr', 60.499414391990157), ('said', 56.741359481832802), ('year', 46.349799118454683), ('company', 39.637610802123596), ('billion', 38.957686391088167), ('companies', 32.219701201541), ('new', 30.746409730386809), ('president', 28.514634159073903), ('investors', 27.036834176094146), ('people', 25.494959739532767), ('business', 24.079700970663392), ('like', 22.548947878838668), ('market', 21.846142100191848), ('deal', 21.063802505389873), ('million', 19.557754571368385), ('services', 18.850764197791335), ('apple', 18.837335866987516), ('growth', 16.622561471633944), ('chief', 16.601072218753693)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 782.6947
# iteration: 2 of max_iter: 10, perplexity: 749.3415
# iteration: 3 of max_iter: 10, perplexity: 739.4212
# iteration: 4 of max_iter: 10, perplexity: 735.1748
# iteration: 5 of max_iter: 10, perplexity: 733.0130
# iteration: 6 of max_iter: 10, perplexity: 731.7919
# iteration: 7 of max_iter: 10, perplexity: 731.0519
# iteration: 8 of max_iter: 10, perplexity: 730.5800
# iteration: 9 of max_iter: 10, perplexity: 730.2671
# iteration: 10 of max_iter: 10, perplexity: 730.0530
# amazon_neg
# Topic 0:
# [('company', 140.0199026913001), ('percent', 105.46821462299494), ('trump', 102.26062816511322), ('mr', 98.236316850673745), ('companies', 80.580622343288113), ('billion', 80.534457461055595), ('new', 71.710935871149843), ('business', 69.297452637705661), ('china', 66.095298590056629), ('year', 64.466006424714422), ('trade', 61.260724216368097), ('president', 59.663736323226956), ('tariffs', 56.430785688069321), ('nyt', 55.638340917392199), ('deal', 52.448976672406509), ('investors', 50.828214326018269), ('toys', 48.399366688745118), ('stock', 47.605779391164674), ('bloomberg', 46.799112020438969), ('like', 46.775786207389814)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 518.6696
# iteration: 2 of max_iter: 10, perplexity: 496.3460
# iteration: 3 of max_iter: 10, perplexity: 489.6538
# iteration: 4 of max_iter: 10, perplexity: 486.7797
# iteration: 5 of max_iter: 10, perplexity: 485.3140
# iteration: 6 of max_iter: 10, perplexity: 484.4852
# iteration: 7 of max_iter: 10, perplexity: 483.9825
# iteration: 8 of max_iter: 10, perplexity: 483.6618
# iteration: 9 of max_iter: 10, perplexity: 483.4490
# iteration: 10 of max_iter: 10, perplexity: 483.3034
# amazon_pos
# Topic 0:
# [('year', 107.86514733692022), ('percent', 103.04519859926783), ('company', 88.622413762403653), ('billion', 74.971851877228275), ('companies', 71.764339000424783), ('new', 66.098374769931567), ('mr', 60.481535550379483), ('online', 58.853534298153896), ('data', 56.46339425814736), ('business', 54.051646666737405), ('million', 52.420330120677775), ('market', 46.802038304074735), ('walmart', 43.595984886698183), ('delivery', 43.590711596785617), ('people', 43.58503054780163), ('like', 42.775981780165594), ('stores', 40.410135032268244), ('sales', 39.559257582932105), ('service', 38.771136315507967), ('share', 38.759834791896466)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 314.5174
# iteration: 2 of max_iter: 10, perplexity: 300.1903
# iteration: 3 of max_iter: 10, perplexity: 295.8805
# iteration: 4 of max_iter: 10, perplexity: 294.0266
# iteration: 5 of max_iter: 10, perplexity: 293.0801
# iteration: 6 of max_iter: 10, perplexity: 292.5446
# iteration: 7 of max_iter: 10, perplexity: 292.2196
# iteration: 8 of max_iter: 10, perplexity: 292.0122
# iteration: 9 of max_iter: 10, perplexity: 291.8746
# iteration: 10 of max_iter: 10, perplexity: 291.7803
# Boeing_neg
# Topic 0:
# [('percent', 102.28807329589441), ('trump', 75.708095360788349), ('mr', 62.87962084790535), ('trade', 62.066161678117361), ('tariffs', 54.039100723960374), ('company', 50.000124985971638), ('new', 48.430826210421486), ('president', 45.987685197059584), ('billion', 44.397868995388762), ('companies', 43.59960684178948), ('year', 41.208903635557654), ('china', 41.199491609553093), ('united', 37.151358365127699), ('steel', 36.385631253109665), ('aluminum', 36.328818686575822), ('million', 33.965146759861369), ('states', 33.131555598483146), ('business', 31.522998321476976), ('investors', 29.101389535303809), ('house', 28.320501258467495)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 136.3118
# iteration: 2 of max_iter: 10, perplexity: 129.0327
# iteration: 3 of max_iter: 10, perplexity: 126.7231
# iteration: 4 of max_iter: 10, perplexity: 125.7071
# iteration: 5 of max_iter: 10, perplexity: 125.1818
# iteration: 6 of max_iter: 10, perplexity: 124.8822
# iteration: 7 of max_iter: 10, perplexity: 124.6994
# iteration: 8 of max_iter: 10, perplexity: 124.5822
# iteration: 9 of max_iter: 10, perplexity: 124.5042
# Boeing_pos
# Topic 0:
# [('year', 28.919638716653971), ('airbus', 26.607131125093574), ('market', 18.100114977994817), ('percent', 17.317481473466579), ('jets', 16.528671305547022), ('aircraft', 16.469607439691071), ('jet', 15.722125185676184), ('business', 15.715549666898625), ('air', 15.004755745338699), ('bombardier', 12.669233456815073), ('president', 12.65685034847664), ('demand', 12.634377155360069), ('company', 12.62738945589847), ('body', 11.893774661115426), ('service', 11.871155414180135), ('airlines', 11.103928369542366), ('reutersmarch', 11.103266559570123), ('government', 11.09810465822601), ('years', 11.079959982525024), ('cost', 11.071315126676529)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 113.4662
# iteration: 2 of max_iter: 10, perplexity: 108.5367
# iteration: 3 of max_iter: 10, perplexity: 107.0471
# iteration: 4 of max_iter: 10, perplexity: 106.4055
# iteration: 5 of max_iter: 10, perplexity: 106.0777
# iteration: 6 of max_iter: 10, perplexity: 105.8921
# iteration: 7 of max_iter: 10, perplexity: 105.7795
# iteration: 8 of max_iter: 10, perplexity: 105.7076
# Google_neg
# Topic 0:
# [('china', 56.049142233319941), ('trump', 38.910307651584901), ('billion', 34.496834121880426), ('companies', 34.420867723547097), ('trade', 33.004364383407875), ('company', 29.238378107929282), ('technology', 25.529464268663006), ('million', 24.804417156854065), ('percent', 24.093317783942304), ('tariffs', 23.310306511664844), ('year', 21.070474758472816), ('business', 19.625535495613516), ('chinese', 18.874599298761037), ('united', 16.641336446276227), ('stock', 16.613466118941016), ('washington', 16.611505381944948), ('states', 16.58487505735728), ('president', 15.921319083570662), ('new', 15.878928770238758), ('administration', 15.863434354182385)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 75.6028
# iteration: 2 of max_iter: 10, perplexity: 71.9424
# iteration: 3 of max_iter: 10, perplexity: 70.8172
# iteration: 4 of max_iter: 10, perplexity: 70.3286
# iteration: 5 of max_iter: 10, perplexity: 70.0779
# iteration: 6 of max_iter: 10, perplexity: 69.9356
# iteration: 7 of max_iter: 10, perplexity: 69.8490
# Google_pos
# Topic 0:
# [('company', 32.641823046891489), ('billion', 28.401064311991664), ('new', 25.680006308957637), ('year', 23.521078583673397), ('like', 22.107319114628719), ('million', 20.712794656675047), ('percent', 17.237520259987207), ('business', 15.81088754487206), ('companies', 15.765742802757501), ('public', 15.098808875184186), ('service', 12.997942003202118), ('businesses', 12.341420603593827), ('media', 12.249479894832479), ('chief', 11.612432438128977), ('time', 10.869343721353843), ('united', 10.196968924583985), ('market', 10.16809975212097), ('based', 9.4980063543408129), ('states', 9.4797397811786048), ('years', 9.472094195018018)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 908.0874
# iteration: 2 of max_iter: 10, perplexity: 870.7442
# iteration: 3 of max_iter: 10, perplexity: 859.6754
# iteration: 4 of max_iter: 10, perplexity: 854.9445
# iteration: 5 of max_iter: 10, perplexity: 852.5381
# iteration: 6 of max_iter: 10, perplexity: 851.1796
# iteration: 7 of max_iter: 10, perplexity: 850.3567
# iteration: 8 of max_iter: 10, perplexity: 849.8321
# iteration: 9 of max_iter: 10, perplexity: 849.4843
# iteration: 10 of max_iter: 10, perplexity: 849.2464
# Facebook_neg
# Topic 0:
# [('percent', 133.60543830022078), ('mr', 119.96153316993558), ('company', 114.32759470373466), ('new', 113.54549242976685), ('trump', 106.26365869406092), ('companies', 95.834748328222929), ('billion', 92.627114379204741), ('year', 89.424362677502899), ('nyt', 85.40337560582465), ('investors', 76.547806804751602), ('president', 70.899896880708809), ('million', 62.09390713115134), ('business', 61.269294975241465), ('like', 58.845619944038972), ('deal', 58.831557982445275), ('bank', 58.060166245893065), ('financial', 58.042024302377854), ('wsj', 55.640902330709558), ('trade', 54.827009894267633), ('china', 54.024330035857005)]
# C:\Users\rajpu\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10, perplexity: 284.2583
# iteration: 2 of max_iter: 10, perplexity: 270.1023
# iteration: 3 of max_iter: 10, perplexity: 265.7810
# iteration: 4 of max_iter: 10, perplexity: 263.9102
# iteration: 5 of max_iter: 10, perplexity: 262.9515
# iteration: 6 of max_iter: 10, perplexity: 262.4078
# iteration: 7 of max_iter: 10, perplexity: 262.0773
# iteration: 8 of max_iter: 10, perplexity: 261.8661
# iteration: 9 of max_iter: 10, perplexity: 261.7258
# iteration: 10 of max_iter: 10, perplexity: 261.6296
# Facebook_pos
# Topic 0:
# [('data', 62.892425265111576), ('year', 50.008652611743535), ('people', 49.207897484072589), ('percent', 46.818675995702655), ('company', 46.010103280642177), ('new', 45.980326868092199), ('mr', 42.766286652767022), ('page', 35.558527567582537), ('like', 34.73855328520655), ('companies', 33.966820777976523), ('million', 33.950034745890605), ('000', 33.181208950670936), ('growth', 29.129482919589108), ('value', 24.322050587500783), ('time', 23.496432213101457), ('apple', 22.696805957058878), ('users', 22.680447125852552), ('billion', 22.675393155883505), ('technology', 21.951486489735156), ('trump', 21.921939366616847)]
